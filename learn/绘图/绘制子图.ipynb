# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
plt.show()

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
plt.show()

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
#plt.subplot(3,1,3)
plt.show()

# %%
import numpy as np
plt.subplot(2,2,1)
x = np.random.random(10)
y = np.random.random(10)
plt.scatter(x,y)   #画散点图

plt.subplot(2,2,2)
x=np.arange(7)
y = x ** 2
plt.plot(x,y)   #画曲线

plt.subplot(2,1,2)


plt.show()
